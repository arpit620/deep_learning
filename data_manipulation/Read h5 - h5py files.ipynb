# %%
import keras

# %%
model = keras.applications.vgg16.VGG16(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
# Out:
# ...
# 553467904/553467096 [==============================] - 218s 0us/step

# %%
keras.applications.inception_v3.InceptionV3(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
# Out:
# ...
# 96116736/96112376 [==============================] - 38s 0us/step

# %%
keras.applications.inception_v3.InceptionV3(include_top=False, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
# Out:
# ...
# 87916544/87910968 [==============================] - 31s 0us/step

# %%
import h5py
import numpy as np

# %%
f = h5py.File(r"C:\Users\username\.keras\models\vgg16_weights_tf_dim_ordering_tf_kernels.h5", "r")

# %%
f.keys()
# Out:
# KeysView(<HDF5 file "vgg16_weights_tf_dim_ordering_tf_kernels.h5" (mode r)>)

# %%
f.name
# Out:
# '/'

# %%
for name in f:
    print(name)
# Out:
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool
# fc1
# fc2
# flatten
# predictions

# %%
f.keys()
# Out:
# KeysView(<HDF5 file "vgg16_weights_tf_dim_ordering_tf_kernels.h5" (mode r)>)

# %%
list(f.keys())
# Out:
# ['block1_conv1',
#  'block1_conv2',
#  'block1_pool',
#  'block2_conv1',
#  'block2_conv2',
#  'block2_pool',
#  'block3_conv1',
#  'block3_conv2',
#  'block3_conv3',
#  'block3_pool',
#  'block4_conv1',
#  'block4_conv2',
#  'block4_conv3',
#  'block4_pool',
#  'block5_conv1',
#  'block5_conv2',
#  'block5_conv3',
#  'block5_pool',
#  'fc1',
#  'fc2',
#  'flatten',
#  'predictions']

# %%
a = list(f.keys())[0]
a
# Out:
# 'block1_conv1'

# %%
list(f['block1_conv1'])
# Out:
# ['block1_conv1_W_1:0', 'block1_conv1_b_1:0']

# %%
list(f['block1_conv1']['block1_conv1_W_1:0'])
# Out:
# [array([[[ 0.42947057,  0.11727387,  0.03401296,  0.35422093,
#           -0.0865837 ,  0.22968295,  0.06683242,  0.04133838,
#            0.13026784,  0.03291035,  0.09615457, -0.09222532,
#           -0.15587331,  0.0522968 , -0.08324417,  0.15728769,
#            0.0291196 ,  0.05094835,  0.19055748, -0.04372229,
#            0.3618031 ,  0.23902874,  0.16667192, -0.18046746,
#            0.04404821,  0.09592837, -0.04381131, -0.1884835 ,
#           -0.04399502, -0.18985446, -0.23386982,  0.12836744,
#           -0.11059975,  0.00571336, -0.24479656, -0.30530283,
#            0.060938  , -0.32816252,  0.1711953 ,  0.10265407,
#           -0.11063665,  0.33012986, -0.05869728,  0.18478717,
#            0.01050853,  0.10668027, -0.13086924, -0.36283946,
#            0.06440807,  0.09335972,  0.00401619,  0.37814805,
#            0.05268804, -0.27078936,  0.11060741, -0.11819526,
#            0.04298935,  0.35323623, -0.28468162, -0.20289008,
# ...

# %%
for name in f['block1_conv1']:
    print(name)
# Out:
# block1_conv1_W_1:0
# block1_conv1_b_1:0

# %%
f['block1_conv1']['block1_conv1_W_1:0']
# Out:
# <HDF5 dataset "block1_conv1_W_1:0": shape (3, 3, 3, 64), type "<f4">

# %%
f['block1_conv1']['block1_conv1_W_1:0'].shape
# Out:
# (3, 3, 3, 64)
